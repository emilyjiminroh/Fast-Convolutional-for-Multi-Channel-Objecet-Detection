# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"
# !python train.py --evaluate  --gpu_idx 0 --pretrained_path=../checkpoints/classic/ClassicalRPN/Model_classic_epoch_300.pth
# Out:
# /src/SFA3D/sfa/utils/eval.py:19: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def get_thresholds(scores: np.ndarray, num_gt, num_sample_pts=41):
# You have chosen a specific GPU. This will completely disable data parallelism.
# 2024-04-29 02:17:19,267: logger.py - info(), at Line 49:INFO:
# >>> Created a new logger
# 2024-04-29 02:17:19,267: logger.py - info(), at Line 49:INFO:
# ...

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"
# !python train.py --gpu_idx 0 --mode cnn --saved_fn Final_Classical
# Out:
# /src/SFA3D/sfa/utils/eval.py:19: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def get_thresholds(scores: np.ndarray, num_gt, num_sample_pts=41):
# You have chosen a specific GPU. This will completely disable data parallelism.
# 2024-04-17 02:05:24,982: logger.py - info(), at Line 49:INFO:
# >>> Created a new logger
# 2024-04-17 02:05:24,982: logger.py - info(), at Line 49:INFO:
# ...
